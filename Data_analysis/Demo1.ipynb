# %% [markdown]
# # Demo
# ## Addition Program

# %%
a=10

# %%
a=10

# %%
a
# Out:
# 10

# %%
b=20

# %%
c=a+b

# %%
c
# Out:
# 30

# %% [markdown]
# # String
# ## Print the "Firstbit" and "Sahil Sayyad"

# %%
str1 ="Firstbut"

# %%
str1
# Out:
# 'Firstbut'

# %%
str1 = "Sahil Sayyd"

# %%
str1
# Out:
# 'Sahil Sayyd'
