# %% [markdown]
# # Demo
#
# ## Topic 1

# %% [markdown]
# This is first day for notebook. we are trying to get used to it

# %% [raw]
# # pip install numpy

# %%
a = 10

# %%
a
# Out:
# 10

# %% [raw]
# b = 20

# %%
b
# Out:
# 10

# %%
b=10
c = a +b
c
# Out:
# 20

# %%
str1 ="Firstbit"

# %%
str1
# Out:
# 'Python'

# %%
str1 ="Python"

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
def findExp(a,b):
    pass

# %%
a =
b = 
result = findExp(a,b)
result
